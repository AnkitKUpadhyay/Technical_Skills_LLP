# %% [markdown]
# <a href="https://colab.research.google.com/github/AnkitKUpadhyay/Technical_Skills_LLP/blob/main/HW_Saver_LLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
path= '/content/drive/MyDrive/LLC'

# %%
path
# Out:
# '/content/drive/MyDrive/LLC'

# %%
dataset= path+'/'+'HW_LLC.zip'

# %%
# !unzip "/content/drive/MyDrive/LLC/HW_LLC.zip"
# Out:
# Archive:  /content/drive/MyDrive/LLC/HW_LLC.zip
#   inflating: Example_Technical_Skills.csv
#   inflating: __MACOSX/._Example_Technical_Skills.csv
#   inflating: Raw_Skills_Dataset.csv
#   inflating: __MACOSX/._Raw_Skills_Dataset.csv

# %%
import os
import pandas as pd

# %%
data_path = os.path.join("..", "content")
skill_df = pd.read_csv(os.path.join(data_path, "Example_Technical_Skills.csv"))

# %%
skill_df
# Out:
#                          Technology Skills
# 0                      SAP Fiori Developer
# 1    Oracle Instance Management & Strategy
# 2             Boomi Master Data Management
# 3    Digital Manufacturing on Cloud ( DMC)
# 4                                   DevOps
# ..                                     ...
# 974        Oracle Cloud Revenue Management
# 975       Oracle EBS Grid Contral Mgt Pack
# 976         Amazon Elastic MapReduce (EMR)
# 977                            Apache Kudu
# 978                             Oracle ESB
#
# [979 rows x 1 columns]

# %%
skill_df.rename(columns = {'Technology Skills':'skills'}, inplace = True)

# %%
skill_df.drop_duplicates(inplace=True)

# %%
len(skill_df)
# Out:
# 897

# %%
list(skill_df)
# Out:
# ['skills']

# %%
skill_df
# Out:
#                                     skills
# 0                      SAP Fiori Developer
# 1    Oracle Instance Management & Strategy
# 2             Boomi Master Data Management
# 3    Digital Manufacturing on Cloud ( DMC)
# 4                                   DevOps
# ..                                     ...
# 974        Oracle Cloud Revenue Management
# 975       Oracle EBS Grid Contral Mgt Pack
# 976         Amazon Elastic MapReduce (EMR)
# 977                            Apache Kudu
# 978                             Oracle ESB
#
# [897 rows x 1 columns]

# %%
val=skill_df.skills

# %%
val.tolist()
# Out:
# ['SAP Fiori Developer',
#  'Oracle Instance Management & Strategy',
#  'Boomi Master Data Management',
#  'Digital Manufacturing on Cloud ( DMC)',
#  'DevOps',
#  'CA SAM',
#  'OpenShift',
#  'Acxiom Data Analytics',
#  'SAP Digital Boardroom',
#  'Seeburger BIS',
#  'SAP Transport Management',
#  'PeopleSoft Workflow',
#  'NICE Actimize',
#  'Oracle - Access Manager',
#  'SAP Electronic Data Interchange (EDI)',
#  'Ideas crowdsourcing',
#  'PeopleSoft Workforce Planning',
#  'SAP Benefits',
#  'ONESOURCE R&D Credit Manager',
#  'SAP Consignment',
#  'MS Bot Framework',
#  'IBM WebSphere Application Server',
#  'Microsoft - Azure AD Domain Services',
#  'SAP IBP / BPC',
#  'Oracle Hyperion Capital Asset Planning',
#  'SAP Introscope Wily',
#  'EJB / RMI',
#  'SAS Base',
#  'Siebel Modules Non Functional Testing',
#  'Oracle Cloud Product Hub Data Steward',
#  'Kronos WFC Accruals Configuration',
#  'JDE Fixed Assets',
#  'SAP TM-EWM Integration',
#  'PeopleSoft Payables',
# ...

# %%
import nltk
import random
all_words = []
for w in val:
    all_words.append(w.lower())

# %%
all_words
# Out:
# ['sap fiori developer',
#  'oracle instance management & strategy',
#  'boomi master data management',
#  'digital manufacturing on cloud ( dmc)',
#  'devops',
#  'ca sam',
#  'openshift',
#  'acxiom data analytics',
#  'sap digital boardroom',
#  'seeburger bis',
#  'sap transport management',
#  'peoplesoft workflow',
#  'nice actimize',
#  'oracle - access manager',
#  'sap electronic data interchange (edi)',
#  'ideas crowdsourcing',
#  'peoplesoft workforce planning',
#  'sap benefits',
#  'onesource r&d credit manager',
#  'sap consignment',
#  'ms bot framework',
#  'ibm websphere application server',
#  'microsoft - azure ad domain services',
#  'sap ibp / bpc',
#  'oracle hyperion capital asset planning',
#  'sap introscope wily',
#  'ejb / rmi',
#  'sas base',
#  'siebel modules non functional testing',
#  'oracle cloud product hub data steward',
#  'kronos wfc accruals configuration',
#  'jde fixed assets',
#  'sap tm-ewm integration',
#  'peoplesoft payables',
# ...

# %%
all_words = nltk.FreqDist(all_words)
all_words
# Out:
# FreqDist({'5g optical/fiber network planning': 1,
#           '5g product management and orchestration': 1,
#           '5g radio access network engineering': 1,
#           '5g radio access network operations': 1,
#           '802.11 security': 1,
#           'abap (bapi)': 1,
#           'abrevity filedata': 1,
#           'activemq': 1,
#           'acxiom data analytics': 1,
#           'adaptable database system (adabas)': 1,
#           'adobe cq': 1,
#           'adobe designer': 1,
#           'adobe digital publishing suite': 1,
#           'adobe experience manager - communities': 1,
#           'adobe lightroom': 1,
#           'adobe photoshop': 1,
#           'adobe sitecatalyst': 1,
#           'adobe software compliance audit': 1,
#           'adobe test & target': 1,
#           'adobe xd': 1,
#           'adp globalview hcm': 1,
#           'advanced persistent threats': 1,
#           'advent geneva': 1,
#           'adversarial simulation': 1,
# ...

# %%
def listToString(s): 
    
    # initialize an empty string
    str1 = "" 
    
    # traverse in the string  
    for ele in s: 
        str1= str1+ele+" "
    
    # return string  
    return str1

# %%
word=listToString(all_words)

# %%
word
# Out:
# 'sap fiori developer oracle instance management & strategy boomi master data management digital manufacturing on cloud ( dmc) devops ca sam openshift acxiom data analytics sap digital boardroom seeburger bis sap transport management peoplesoft workflow nice actimize oracle - access manager sap electronic data interchange (edi) ideas crowdsourcing peoplesoft workforce planning sap benefits onesource r&d credit manager sap consignment ms bot framework ibm websphere application server microsoft - azure ad domain services sap ibp / bpc oracle hyperion capital asset planning sap introscope wily ejb / rmi sas base siebel modules non functional testing oracle cloud product hub data steward kronos wfc accruals configuration jde fixed assets sap tm-ewm integration peoplesoft payables netsuite case management mysql escalations and notifications ms sql reporting services sap convergent charging cc big data software architecture cp3 migration documentation (mfd) hyperion web analysis & reporting
# ...

# %%
import re
xmasRegex = re.compile(r'\w{3,}\s')
result=xmasRegex.findall(word)

# %%
all=listToString(result)

# %%
all
# Out:
# 'sap  fiori  developer  oracle  instance  management  strategy  boomi  master  data  management  digital  manufacturing  cloud  devops  sam  openshift  acxiom  data  analytics  sap  digital  boardroom  seeburger  bis  sap  transport  management  peoplesoft  workflow  nice  actimize  oracle  access  manager  sap  electronic  data  interchange  ideas  crowdsourcing  peoplesoft  workforce  planning  sap  benefits  onesource  credit  manager  sap  consignment  bot  framework  ibm  websphere  application  server  microsoft  azure  domain  services  sap  ibp  bpc  oracle  hyperion  capital  asset  planning  sap  introscope  wily  ejb  rmi  sas  base  siebel  modules  non  functional  testing  oracle  cloud  product  hub  data  steward  kronos  wfc  accruals  configuration  jde  fixed  assets  sap  ewm  integration  peoplesoft  payables  netsuite  case  management  mysql  escalations  and  notifications  sql  reporting  services  sap  convergent  charging  big  data  software  architecture 
# ...

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt')
tokz=word_tokenize(all)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
freq_words = nltk.FreqDist(tokz)
freq_words
# Out:
# FreqDist({'sap': 132,
#           'fiori': 1,
#           'developer': 4,
#           'oracle': 90,
#           'instance': 1,
#           'management': 54,
#           'strategy': 2,
#           'boomi': 2,
#           'master': 3,
#           'data': 55,
#           'digital': 3,
#           'manufacturing': 4,
#           'cloud': 54,
#           'devops': 1,
#           'sam': 2,
#           'openshift': 1,
#           'acxiom': 1,
#           'analytics': 21,
#           'boardroom': 1,
#           'seeburger': 1,
#           'bis': 1,
#           'transport': 1,
#           'peoplesoft': 22,
#           'workflow': 5,
#           'nice': 1,
#           'actimize': 1,
#           'access': 7,
#           'manager': 11,
#           'electronic': 2,
#           'interchange': 1,
#           'ideas': 1,
#           'crowdsourcing': 1,
#           'workforce': 2,
#           'planning': 11,
#           'benefits': 5,
#           'onesource': 4,
#           'credit': 2,
# ...

# %%
len(freq_words)
# Out:
# 1106

# %%
freq_words.most_common(140)
# Out:
# [('sap', 132),
#  ('oracle', 90),
#  ('data', 55),
#  ('management', 54),
#  ('cloud', 54),
#  ('peoplesoft', 22),
#  ('analytics', 21),
#  ('microsoft', 21),
#  ('ibm', 19),
#  ('siebel', 19),
#  ('ebs', 19),
#  ('integration', 18),
#  ('and', 18),
#  ('netsuite', 17),
#  ('security', 17),
#  ('jde', 16),
#  ('testing', 15),
#  ('azure', 14),
#  ('design', 14),
#  ('service', 14),
#  ('application', 13),
#  ('software', 13),
#  ('apache', 13),
#  ('services', 12),
#  ('reporting', 12),
#  ('manager', 11),
#  ('planning', 11),
#  ('cerner', 11),
#  ('servicenow', 11),
#  ('hana', 11),
#  ('server', 10),
#  ('center', 10),
#  ('adobe', 10),
#  ('network', 10),
#  ('business', 10),
#  ('com', 10),
#  ('enterprise', 10),
#  ('mgmt', 10),
#  ('compliance', 9),
#  ('performance', 9),
#  ('hcm', 9),
#  ('database', 9),
#  ('tax', 9),
#  ('crm', 8),
#  ('customer', 8),
#  ('access', 7),
#  ('product', 7),
#  ('architecture', 7),
#  ('opentext', 7),
#  ('systems', 7),
#  ('warehouse', 7),
# ...

# %%
poss=[]
for w in (freq_words.most_common(140)):
  poss.append(w)

# %%
poss
# Out:
# [('sap', 132),
#  ('oracle', 90),
#  ('data', 55),
#  ('management', 54),
#  ('cloud', 54),
#  ('peoplesoft', 22),
#  ('analytics', 21),
#  ('microsoft', 21),
#  ('ibm', 19),
#  ('siebel', 19),
#  ('ebs', 19),
#  ('integration', 18),
#  ('and', 18),
#  ('netsuite', 17),
#  ('security', 17),
#  ('jde', 16),
#  ('testing', 15),
#  ('azure', 14),
#  ('design', 14),
#  ('service', 14),
#  ('application', 13),
#  ('software', 13),
#  ('apache', 13),
#  ('services', 12),
#  ('reporting', 12),
#  ('manager', 11),
#  ('planning', 11),
#  ('cerner', 11),
#  ('servicenow', 11),
#  ('hana', 11),
#  ('server', 10),
#  ('center', 10),
#  ('adobe', 10),
#  ('network', 10),
#  ('business', 10),
#  ('com', 10),
#  ('enterprise', 10),
#  ('mgmt', 10),
#  ('compliance', 9),
#  ('performance', 9),
#  ('hcm', 9),
#  ('database', 9),
#  ('tax', 9),
#  ('crm', 8),
#  ('customer', 8),
#  ('access', 7),
#  ('product', 7),
#  ('architecture', 7),
#  ('opentext', 7),
#  ('systems', 7),
#  ('warehouse', 7),
# ...

# %%
unzipped_object = zip(*poss)
unzipped_list = list(unzipped_object)

# %%
poss2=unzipped_list[0]

# %%
poss3=list(poss2)

# %%
poss3
# Out:
# ['sap',
#  'oracle',
#  'data',
#  'management',
#  'cloud',
#  'peoplesoft',
#  'analytics',
#  'microsoft',
#  'ibm',
#  'siebel',
#  'ebs',
#  'integration',
#  'and',
#  'netsuite',
#  'security',
#  'jde',
#  'testing',
#  'azure',
#  'design',
#  'service',
#  'application',
#  'software',
#  'apache',
#  'services',
#  'reporting',
#  'manager',
#  'planning',
#  'cerner',
#  'servicenow',
#  'hana',
#  'server',
#  'center',
#  'adobe',
#  'network',
#  'business',
#  'com',
#  'enterprise',
#  'mgmt',
#  'compliance',
#  'performance',
#  'hcm',
#  'database',
#  'tax',
#  'crm',
#  'customer',
#  'access',
#  'product',
#  'architecture',
#  'opentext',
#  'systems',
#  'warehouse',
#  'system',
#  'guidewire',
#  'successfactors',
#  'murex',
#  'development',
#  'hyperion',
#  'asset',
#  'ewm',
#  'big',
#  'process',
#  'meditech',
#  'information',
#  'suite',
#  'marketing',
#  'workflow',
#  'benefits',
#  'ibp',
#  'sas',
#  'functional',
#  'web',
#  'analysis',
# ...

# %%
data_path = os.path.join("..", "content")
raw_skills=pd.read_csv(os.path.join(data_path, "Raw_Skills_Dataset.csv"))

# %%
raw_skills
# Out:
#                                             RAW DATA
# 0                                           What ifs
# 1                                          seniority
# 2                                        familiarity
# 3                                    functionalities
# 4                                            Lambdas
# ...                                              ...
# 34111                                    negotiation
# 34112                                      deadlines
# 34113  Self-motivated, enthusiastic and strong drive
# 34114                                    negotiation
# 34115                                      deadlines
#
# [34116 rows x 1 columns]

# %%
raw_skills.rename(columns = {'RAW DATA':'skills'}, inplace = True)

# %%
raw_skills.drop_duplicates(inplace=True)

# %%
len(raw_skills)
# Out:
# 15677

# %%
val2=raw_skills.skills

# %%
val2.tolist()
# Out:
# ['What ifs',
#  'seniority',
#  'familiarity',
#  'functionalities',
#  'Lambdas',
#  'Java Streams',
#  'Object Oriented analysis',
#  'Relational Databases',
#  'SQL',
#  'ORM',
#  'JPA2',
#  'Hibernate',
#  'MyBatis',
#  'code versioning tools',
#  'Git.. Familiarity',
#  'Maven',
#  'Gradle.. Familiarity',
#  'continuous integration',
#  'continuous delivery development processes',
#  'jenkins',
#  'bamboo',
#  'Familiarity',
#  'frameworks',
#  'transformations',
#  'analytical reporting',
#  'conceptual data models',
#  'standard naming conventions',
#  'coding practices',
#  'consistency',
#  'optimized solutions',
#  'methodologies',
#  'high throughput data access services',
#  'analyze/profile data',
#  'conceptual, logical & physical data model designs',
#  'reporting and analytics solutions',
#  'physical databases',
#  'variances',
#  'discrepancies',
#  'all phases',
#  'integrations',
#  'Demonstrable experience',
#  'logical and physical data models',
# ...

# %%
test_skills = []
for w in val2:
    test_skills.append(w.lower())

# %%
test_skills
# Out:
# ['what ifs',
#  'seniority',
#  'familiarity',
#  'functionalities',
#  'lambdas',
#  'java streams',
#  'object oriented analysis',
#  'relational databases',
#  'sql',
#  'orm',
#  'jpa2',
#  'hibernate',
#  'mybatis',
#  'code versioning tools',
#  'git.. familiarity',
#  'maven',
#  'gradle.. familiarity',
#  'continuous integration',
#  'continuous delivery development processes',
#  'jenkins',
#  'bamboo',
#  'familiarity',
#  'frameworks',
#  'transformations',
#  'analytical reporting',
#  'conceptual data models',
#  'standard naming conventions',
#  'coding practices',
#  'consistency',
#  'optimized solutions',
#  'methodologies',
#  'high throughput data access services',
#  'analyze/profile data',
#  'conceptual, logical & physical data model designs',
#  'reporting and analytics solutions',
#  'physical databases',
#  'variances',
#  'discrepancies',
#  'all phases',
#  'integrations',
#  'demonstrable experience',
#  'logical and physical data models',
# ...

# %%
final_list=[]

# %%
for i in range(len(test_skills)):
  for word in (list_of_words):
    sentence=test_skills[i]
    if word in sentence:
      final_list.append(sentence)

# %%
my_final_list = set(final_list)
list(my_final_list)
# Out:
# ['build and architect systems',
#  'appropriate validation requirements',
#  'software specifications',
#  'no-sql',
#  'appropriate technical/analytical skills',
#  'product analytics',
#  'the full conversion lifecycle',
#  'agile and scrum project management',
#  'aoda testing',
#  'infrastructure readiness',
#  'all non-exceptional service conditions',
#  'quick iterative delivery',
#  'deployment and technical assistance',
#  'recruitment efforts',
#  'thorough knowledge',
#  'daily/monthly reporting suite',
#  'unit testing frameworks',
#  'e.g. javascript',
#  'bachelors - information systems',
#  'reactnative cross-platform mobile development',
#  'the hinge health mobile application',
#  'cross functional global and remote teams',
#  'openembedded-core project',
#  'most protocols',
#  'one or more full release project life cycles',
#  'technical/ project constraints',
#  'sql / nosql database knowledge',
#  'hands-on 1hour series',
#  'microprocessor',
# ...

# %%
df = pd.DataFrame(my_final_list)
df
# Out:
#                                                0
# 0                    build and architect systems
# 1            appropriate validation requirements
# 2                        software specifications
# 3                                         no-sql
# 4        appropriate technical/analytical skills
# ...                                          ...
# 7481                      database schema design
# 7482                        understanding basics
# 7483             enterprise anti-virus solutions
# 7484            javascript/typescript frameworks
# 7485  agile, continuous integration/distribution
#
# [7486 rows x 1 columns]

# %%
df.to_csv('submission.csv', index=False)
